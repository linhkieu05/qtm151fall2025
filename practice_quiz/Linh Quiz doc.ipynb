# %% [markdown]
#  <font size ="5"> This is my first Jupyter Notebook

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
#Q1
# #Use an if/elif/else block to test whether a string belongs to one of two lists. 
# Depending on the outcome (belongs to list A, belongs to list B, doesn't belong to 
# either list) print an appropriate message to the screen

list_1 = ["blue", "red", "green"]
list_2 = ["blue", "red", "green"]
list_3 = ["red", "green", "blue"]
list_4 = ["red", "green", "blue", "violet"]

# e.g. Ask the user to enter a color. 
# Use an if/elif/else block to check:
# - If the color is in list_A → print "This color belongs to list A."
# - If the color is in list_B → print "This color belongs to list B."
# - Otherwise → print "This color does not belong to either list."

#choose "red"

colour = "violet"
if colour in list_1:
    print("This color belongs to list A")
elif colour in list_4:
    print ("This colour belongs to list B")
else:
    print ("This colour does not belong to either list ")


# For colours present in both lists 

colour = "red"
if (colour in list_1) and (colour in list_2):
    print ("In both lists")
elif (colour in list_1) and  (colour not in list_2):
    print ("Only List 1")
elif (colour not in list_1) and (colour in list_2):
    print ("Only List 2")
else:
    print ("In neither list")
# Out:
# This colour belongs to list B
# In both lists

# %%
#Q2
#You are given two lists of numbers, x_vals and y_vals, and must create a 
# Numpy array where the components are related to those in the lists 
# (for example, you might be asked to create a Numpy array with entries Zk = (xk)^2 -5sin(yk))
# then generate a histogram of the values in the Numpy array, with labeled axes and a title. 
# you will also be asked to change the color of the bars in the histogram

# The most common way to create a Numpy array is to convert a list into a numpy array.

list_of_numbers = [5.6, 2.9, 9.7, -10, 0, 3]
array_of_numbers = np.array(list_of_numbers)

array_1 = np.array([2, 3, 5, 11])
array_2 = np.array([1, -4, 2, 0])

# The "+" operation adds the elements of the two arrays together
print(array_1 + array_2)

#math functions
print(np.log(2))
print(np.exp(2))
print(np.sin(2))
print(np.cos(2))
print(np.sqrt(2))
print(np.pi) # pi = circle's circumference/circle's diameter
print(np.e) # Euler's number = limit of (1 + 1/n)^n as n goes to infinity

c_vec = np.array([4.2, 1.2, 11.45, -2, 0, 9, 3.3, 2*np.pi]) # last element is pi
print(np.mean(c_vec))
# we can also compute:
print(np.std(c_vec)) # standard deviation
print(np.median(c_vec)) # median
print(np.max(c_vec)) # maximum
print(np.min(c_vec)) # minimum
# Out:
# <class 'numpy.ndarray'>

# %%
#Q2 continued
x_vals = np.linspace(0, 2*np.pi, 100)   # 100 points between 0 and 2π
y_vals = np.linspace(0, np.pi, 100)

#convert to numpy arrays 
x = np.array(x_vals)
y = np.array(y_vals)

z = (x**2) - 5 * np.sin(y)
print(type(x_vals))
print(type(y_vals))

plt.hist(z, color = "pink")
plt.title("")
plt.xlabel("")
plt.ylabel("")
plt.show()
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# (array([44., 10.,  8.,  7.,  6.,  6.,  5.,  5.,  4.,  5.]),
#  array([-1.40429526,  2.68397602,  6.77224731, 10.8605186 , 14.94878988,
#         19.03706117, 23.12533246, 27.21360374, 31.30187503, 35.39014632,
#         39.4784176 ]),
#  <BarContainer object of 10 artists>)

# %%
# Q3
# Generate random samples from two specified distributions and plot their 
# histograms, side by side in a single figure. Each sub-figure will have its 
# own labeled axes and title

# Set sample size
n = 10000

# Draw n samples from normal distribution with mean = -2, s.d. = 6
normal_samples = np.random.normal(loc = -2, scale = 6, size = n)

# Draw n samples from chi-squared distribution with 4 degrees of freedom
chisqr_samples = np.random.chisquare(df = 4, size = n)

# Draw n samples from uniform distribution with a = -3, b = 5
unif_samples = np.random.uniform(low = -3, high = 5, size = n)


#histogram question in assignment 4
# Sample Size 100

np.random.seed(1234) # set the seed for reproducibility
num_simulations = 2000

# complete the code
sz = 100
vec_xbar = np.zeros(num_simulations)


for iteration in range(num_simulations):
    vec_unif  = np.random.lognormal(mean = 1, sigma=0.5, size = sz)
    vec_xbar[iteration] = vec_unif.mean()

plt.hist(x = vec_xbar)
plt.title("Distribution of Xbar with sample size " + str(sz))
plt.ylabel("Frequency")
plt.xlabel("Values of Xbar")
plt.xlim(xmin_plt, xmax_plt)
plt.ylim(top = ymax_plt)
plt.show()

# %%
#Q3 continued
#1. Generate 1000 random samples from each of two distributions:
#    - a Normal distribution with mean = 0 and standard deviation = 1
#    - a Uniform distribution between -3 and 3
# 2. Plot their histograms side by side
n = 10000

normal_samples = np.random.normal(loc = 0, scale = 1, size = n)
unif_samples = np.random.uniform(low = -3, high = 3, size = n)

#Create sub figures
# plt.subplots has TWO outputs, so we assign the output to TWO variables
# The names we give them are OUR CHOICE
# The option "figsize" indicates the (width,height)) of the graph.
# The complete figure will be 6 inches wide, 3 inches tall

fig, subfig_array = plt.subplots(nrows = 1, ncols = 2,figsize = (6,3))

# First Sub-Figure
subfig_array[0].hist(x = normal_samples)
subfig_array[0].set_title("Normal Distribution\n with mean 0, s.d. 1")
subfig_array[0].set_xlabel("Sample Value")
subfig_array[0].set_ylabel("Frequency")

# Second sub-figure
subfig_array[1].hist(x = unif_samples)
subfig_array[1].set_title("Uniform Distribution\n over [-3, 3]")
subfig_array[1].set_xlabel("Sample Value")
subfig_array[1].set_ylabel("Frequency")

# The tight layout option ensures that the axes are not overlapping
plt.tight_layout()

# %%
#Q4
#Read in a .csv file to create a Pandas DataFrame. Create a scatter plot with one 
# of the variables (or features) corresponding to the x-axis and another 
# corresponding to the y-axis. The plot should have a title and labeled axes.

us_emissions = pd.read_csv('practice_quiz_data/united_states_co2_emissions.csv')

# We use square brackets [...] to subset information from data 
# Text/strings have to be written in quotation marks
# This command extracts the column 'cylinders'

carfeatures["cylinders"]

plt.scatter(x = carfeatures['weight'], y = carfeatures['mpg'])
plt.xlabel("weight(pounds)")
plt.ylabel("mpg")
plt.title("relationship...")
plt.show()

plt.scatter(x = carfeatures['acceleration'], y = carfeatures['mpg'])
plt.show()

# %%
#Q5
#Read in a .csv file to create a Pandas DataFrame. Loop over a list of 
# variable/column names, printing the mean of each variable.

carfeatures = pd.read_csv("practice_quiz_data/features1.csv")
columns = ["displacement", "weight", "acceleration"]

for feature in columns:
    mean_values = (carfeatures[columns].mean())

print(mean_values)
# Out:
# displacement     193.427136
# weight          2970.424623
# acceleration      15.568090
# dtype: float64

# %%
china_emissions = pd.read_csv("practice_quiz_data/china_co2_emissions.csv")
germany_emissions = pd.read_csv("practice_quiz_data/germany_co2_emissions.csv")
india_emissions = pd.read_csv("practice_quiz_data/india_co2_emissions.csv")

# %%
#Q6
#Create a list of .csv file names and an additional empty list. 
# Then in a for loop, read in each file to make a DataFrame
# compute the mean of one of the variables/features/columns
# store it as an element of the originally empty list. 
# Then print the list. 

csv_files = [china_emissions, germany_emissions, india_emissions]
mean_emissions = []

for file in csv_files:
    mean_values = str(file["total_emissions"].mean())
    mean_emissions.append(mean_values)

print(mean_emissions)
# Out:
# ['3599957.523613542', '812234.0017903647', '802812.5477612636']
